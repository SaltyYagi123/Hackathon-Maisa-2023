# %% [markdown]
# ## Extracción de datos de AP news, The Independent, CNN España

# %%
import requests
import newspaper
import pandas as pd 

from newspaper import Article
from bs4 import BeautifulSoup
import re

# %%
# * Careful because these aren't articles, they are portals
news_sources_world = {
    'bbc': 'https://www.bbc.com/news/world',
    'time':'https://time.com/section/world',
    'france24':'https://www.france24.com/en/world',
    'apnews': 'https://apnews.com/world-news',
    'the_independent': 'https://www.independent.co.uk/world',
    'cnn_espana': 'https://cnnespanol.cnn.com/seccion/mundo/'
}

# %%
news_sources_world = {
    'bbc': 'https://www.bbc.com/news/world',
    'time':'https://time.com/section/world',
    'france24':'https://www.france24.com/en/',
    'apnews': 'https://apnews.com/world-news',
    'the_independent': 'https://www.independent.co.uk/world',
    'cnn_espana': 'https://cnnespanol.cnn.com/seccion/mundo/'
}


def scrape_bbc(url):
    """Scrape BBC for article links."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
        
    # Encontrar todos los enlaces <a> que contienen noticias
    enlaces = soup.find_all('a', href=True)
        
    # Definir patrones de expresiones regulares para las clases parciales
    clase_promo = re.compile(r'.*PromoLink.*')
    clase_post = re.compile(r'.*LinkPostLink.*')
        
    # Filtrar los enlaces que contienen las clases parciales y no comienzan con "https"
    links = ["https://www.bbc.com" + enlace['href'] for enlace in enlaces if (clase_promo.match(' '.join(enlace.get('class', []))) or clase_post.match(' '.join(enlace.get('class', [])))) and not enlace['href'].startswith('https')]
    return links

def scrape_time(url):
    """Scrape Time for article links."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    divs = soup.find_all('div', class_='taxonomy-tout')
    
    links = []
    for div in divs:
        enlace = div.find('a', href=True)
        if enlace:
            links.append("https://time.com" + enlace['href'])
    return links

def scrape_france24(url):
    # Definir el encabezado de agente de usuario, si lo quitas es 403
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    # Realizar solicitud HTTP a la página web con el encabezado de agente de usuario
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    enlaces = soup.find_all('a', href=True, attrs={'data-article-item-link': True})
    
    links = []
    for enlace in enlaces:
        enlace_completo = "https://www.france24.com" + enlace['href']
        if enlace_completo not in links:  # Verificar si el enlace es nuevo
            links.append(enlace_completo)  # Agregar a la lista de enlaces a retornar
    return links

def scrape_apnews(url):
    """Scrape AP News for article links."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = [a['href'] for a in soup.find_all('a', href=True) if a.parent.name == 'h3' and 'PagePromo-title' in a.parent.get('class', [])]
    return links

def scrape_the_independent(url):
    """Scrape The Independent for article links."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = ['https://www.independent.co.uk' + a['href'] for a in soup.find_all('a', class_='title')]
    return links

def scrape_cnn_espana(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = [a['href'] for a in soup.find_all('a', href=True) if 'news__media-item' in a.get('class', []) or (a.parent.name == 'h2' and 'news__title' in a.parent.get('class', []))]
    return links


def extract_articles_from_sources():
    
    bbc_links = scrape_bbc(news_sources_world['bbc'])
    time_links = scrape_time(news_sources_world['time'])
    france24_links = scrape_france24(news_sources_world['france24'])
    apnews_links = scrape_apnews(news_sources_world['apnews'])
    the_independent_links = scrape_the_independent(news_sources_world['the_independent'])
    cnn_espana_links = scrape_cnn_espana(news_sources_world['cnn_espana'])
    
    #print('The Independent Links:', the_independent_links)
    #print('AP News Links:', apnews_links)
    #print('CNN España Links:', cnn_espana_links)
    articles = {'bbc_articles':bbc_links, 'time_articles':time_links, 'france24_articles':france24_links, 'ap_news_articles': apnews_links, 'the_independent_articles': the_independent_links,'cnn_espana_articles': cnn_espana_links}
    return articles

# %%
print("Articles from the WORLD news page from today:")
extract_articles_from_sources()
# Out:
# Articles from the WORLD news page from today:
# {'bbc_articles': ['https://www.bbc.com/news/world-europe-68423229',
#   'https://www.bbc.com/news/world-europe-68425869',
#   'https://www.bbc.com/news/world-us-canada-68428697',
#   'https://www.bbc.com/news/world-us-canada-68422118',
#   'https://www.bbc.com/news/world-europe-68423990',
#   'https://www.bbc.com/news/world-africa-68353437',
#   'https://www.bbc.com/news/world-us-canada-68420543',
#   'https://www.bbc.com/news/world-europe-68428670',
#   'https://www.bbc.com/news/world-africa-68424863',
#   'https://www.bbc.com/news/world-australia-68420791',
#   'https://www.bbc.com/news/world-us-canada-68420519',
#   'https://www.bbc.com/news/world-asia-68402139',
#   'https://www.bbc.com/news/world-middle-east-68419581',
#   'https://www.bbc.com/news/world-middle-east-68401909',
#   'https://www.bbc.com/news/world-middle-east-68380776',
#   'https://www.bbc.com/news/world-middle-east-68375460',
#   'https://www.bbc.com/news/world-europe-68425869',
#   'https://www.bbc.com/news/world-europe-68419267',
#   'https://www.bbc.com/news/world-us-canada-68374453',
#   'https://www.bbc.com/news/world-us-canada-68412713',
#   'https://www.bbc.com/news/world-asia-india-68401286',
#   'https://www.bbc.com/news/world-europe-68415802',
#   'https://www.bbc.com/news/world-africa-68374316',
#   'https://www.bbc.com/news/business-68401814',
#   'https://www.bbc.com/news/world-middle-east-68402016',
#   'https://www.bbc.com/news/science-environment-68406880',
#   'https://www.bbc.com/news/uk-england-68429627',
#   'https://www.bbc.com/news/world-us-canada-68421022',
#   'https://www.bbc.com/news/technology-68428536',
#   'https://www.bbc.com/news/world-africa-68424115',
#   'https://www.bbc.com/news/world-africa-68424863',
#   'https://www.bbc.com/news/world-europe-68428670',
#   'https://www.bbc.com/news/world-europe-68423990',
#   'https://www.bbc.com/news/world-africa-68353437',
#   'https://www.bbc.com/news/world-us-canada-68388608',
#   'https://www.bbc.com/news/uk-68426455',
#   'https://www.bbc.com/news/world-europe-68425869',
#   'https://www.bbc.com/news/world-europe-68423229',
#   'https://www.bbc.com/news/world-us-canada-68419279',
#   'https://www.bbc.com/news/world-australia-68420791',
#   'https://www.bbc.com/news/world-europe-68422272',
#   'https://www.bbc.com/news/world-latin-america-68423249',
#   'https://www.bbc.com/news/world-africa-68400220',
#   'https://www.bbc.com/news/world-us-canada-68422977',
#   'https://cnnespanol.cnn.com/video/ranking-5-paises-con-las-mujeres-mas-altas-redaccion-buenos-aires-tv/']}

# %% [markdown]
# ## Preprocessing from the newspapers3k API:

# %%
def extract_article_details(url):
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()
    article_details = {
        'title':article.title, 
        'text': article.text, 
        'authors': article.authors, 
        'date': article.publish_date, 
        'keywords': article.keywords
    }
    return article_details

# %%
def process_article_urls(article_urls_dict):
    articles_data = []

    for source, urls in article_urls_dict.items():
        for url in urls:
            try:
                article_details = extract_article_details(url)
                article_details['source'] = source  # Adding the source information
                articles_data.append(article_details)
            except Exception as e:
                print(f"Failed to process {url} from {source}: {str(e)}")
    
    return articles_data

# %%
articles_data = process_article_urls(extract_articles_from_sources())
df = pd.DataFrame(articles_data)

df.head()
# Out:
# Failed to process https://www.france24.com//observers.france24.com/en/tv-shows/the-observers/20240227-gaza-why-are-israeli-protesters-blocking-humanitarian-aid-for-gaza from france24_articles: Article `download()` failed with 404 Client Error: Not Found for url: https://www.france24.com//observers.france24.com/en/tv-shows/the-observers/20240227-gaza-why-are-israeli-protesters-blocking-humanitarian-aid-for-gaza on URL https://www.france24.com//observers.france24.com/en/tv-shows/the-observers/20240227-gaza-why-are-israeli-protesters-blocking-humanitarian-aid-for-gaza
# Failed to process https://www.france24.com//observers.france24.com/en/asia-pacific/20240220-misinformation-endangering-rohingya-refugees-indonesia from france24_articles: Article `download()` failed with 404 Client Error: Not Found for url: https://www.france24.com//observers.france24.com/en/asia-pacific/20240220-misinformation-endangering-rohingya-refugees-indonesia on URL https://www.france24.com//observers.france24.com/en/asia-pacific/20240220-misinformation-endangering-rohingya-refugees-indonesia
# Failed to process https://www.france24.com//observers.france24.com/en/americas/20240216-debunked-chile-fire-wildfires-blue-paint-immune from france24_articles: Article `download()` failed with 404 Client Error: Not Found for url: https://www.france24.com//observers.france24.com/en/americas/20240216-debunked-chile-fire-wildfires-blue-paint-immune on URL https://www.france24.com//observers.france24.com/en/americas/20240216-debunked-chile-fire-wildfires-blue-paint-immune
# Failed to process https://www.france24.comhttps://www.emmaus-indignaction.org/en/ from france24_articles: Article `download()` failed with HTTPSConnectionPool(host='www.france24.comhttps', port=443): Max retries exceeded with url: //www.emmaus-indignaction.org/en/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000029985A3EF10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')) on URL https://www.france24.comhttps://www.emmaus-indignaction.org/en/
# Failed to process https://www.france24.comhttps://museemaillol.com/en/expositions/cheri-samba-in-the-jean-pigozzi-collection/ from france24_articles: Article `download()` failed with HTTPSConnectionPool(host='www.france24.comhttps', port=443): Max retries exceeded with url: //museemaillol.com/en/expositions/cheri-samba-in-the-jean-pigozzi-collection/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000029985A3EDC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')) on URL https://www.france24.comhttps://museemaillol.com/en/expositions/cheri-samba-in-the-jean-pigozzi-collection/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 articles_data = process_article_urls(extract_articles_from_sources())
#       2 df = pd.DataFrame(articles_data)
#       4 df.head()
#
# Cell In[19], line 7, in process_article_urls(article_urls_dict)
#       5 for url in urls:
#       6     try:
# ----> 7         article_details = extract_article_details(url)
#       8         article_details['source'] = source  # Adding the source information
#       9         articles_data.append(article_details)
#
# Cell In[18], line 3, in extract_article_details(url)
#       1 def extract_article_details(url):
#       2     article = Article(url)
# ----> 3     article.download()
#       4     article.parse()
#       5     article.nlp()
#
# File c:\Anaconda\lib\site-packages\newspaper\article.py:170, in Article.download(self, input_html, title, recursion_counter)
#     168 if input_html is None:
#     169     try:
# --> 170         html = network.get_html_2XX_only(self.url, self.config)
#     171     except requests.exceptions.RequestException as e:
#     172         self.download_state = ArticleDownloadState.FAILED_RESPONSE
#
# File c:\Anaconda\lib\site-packages\newspaper\network.py:62, in get_html_2XX_only(url, config, response)
#      59 if response is not None:
#      60     return _get_html_from_response(response)
# ---> 62 response = requests.get(
#      63     url=url, **get_request_kwargs(timeout, useragent, proxies, headers))
#      65 html = _get_html_from_response(response)
#      67 if config.http_success_only:
#      68     # fail if HTTP sends a non 2XX response
#
# File c:\Anaconda\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Anaconda\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Anaconda\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Anaconda\lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File c:\Anaconda\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Anaconda\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Anaconda\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File c:\Anaconda\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File c:\Anaconda\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Anaconda\lib\http\client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File c:\Anaconda\lib\http\client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File c:\Anaconda\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Anaconda\lib\ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Anaconda\lib\ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df.tail()
# Out:
#                                                  title  \
# 328  Japón registra un mínimo histórico de natalida...
# 329  La Policía de Australia encuentra restos en la...
# 330  La Policía de Australia encuentra restos en la...
# 331  ANÁLISIS | Los peligrosos paralelismos entre l...
# 332  ANÁLISIS | Los peligrosos paralelismos entre l...
#
#                                                   text  \
# 328  Japón le paga a familias para que salgan de To...
# 329  Luke Davies, izquierda, y Jesse Baird fueron v...
# 330  Luke Davies, izquierda, y Jesse Baird fueron v...
# 331  Vladimir Putin y Xi Jinping, dos líderes fuert...
# 332  Vladimir Putin y Xi Jinping, dos líderes fuert...
#
#                         authors                 date  \
# 328  [Melissa Velásquez Loaiza]  2024-02-27 00:00:00
# 329  [Melissa Velásquez Loaiza]  2024-02-27 00:00:00
# 330  [Melissa Velásquez Loaiza]  2024-02-27 00:00:00
# 331  [Melissa Velásquez Loaiza]  2024-02-27 00:00:00
# 332  [Melissa Velásquez Loaiza]  2024-02-27 00:00:00
#
#                                               keywords               source
# 328  [es, una, la, que, los, octavo, registra, nata...  cnn_espana_articles
# 329  [se, por, una, del, los, y, pareja, gay, resto...  cnn_espana_articles
# 330  [se, por, una, del, los, y, pareja, gay, resto...  cnn_espana_articles
# 331  [sobre, reclamaciones, que, una, los, en, puti...  cnn_espana_articles
# 332  [sobre, reclamaciones, que, una, los, en, puti...  cnn_espana_articles

# %% [markdown]
# NEWS API exploration
# Posible exploración para conectar al agente, a la hora de extraer las noticias de manera más generalista:

# %%
news_api_key = '6ddc83d9e2974d0fabbac57924805fa3'

# %%
def search_articles(query, from_date, to_date, language='en',page_size=50):
    base_url = "https://newsapi.org/v2/everything?"
    api_key = news_api_key
    
    # Constructing the API request URL with parameters
    search_url = f"{base_url}q={query}&from={from_date}&to={to_date}&language={language}&apiKey={api_key}&pageSize={page_size}"
    print(search_url)
    # Making the request to NewsAPI
    response = requests.get(search_url)
    
    # Checking if the request was successful
    if response.status_code == 200:
        return response.json()  # Return the JSON response if successful
    else:
        return None

# %%
# Example usage:
from_date = "2024-02-01"
to_date = "2024-02-27"
query = "Ábalos&PSOE"
articles_response = search_articles(query, from_date, to_date, 'es')

if articles_response:
    # Loop through the articles and print some details
    for article in articles_response['articles']:
        print(f"Title: {article['title']}")
        print(f"Author: {article['author']}")
        print(f"Published At: {article['publishedAt']}")
        print(f"Source: {article['source']['name']}")
        print(f"URL: {article['url']}\n")
else:
    print("Failed to retrieve articles")
# Out:
# https://newsapi.org/v2/everything?q=Ábalos&PSOE&from=2024-02-01&to=2024-02-27&language=es&apiKey=6ddc83d9e2974d0fabbac57924805fa3
# Title: Ábalos no cede a la presión del PSOE y mantiene su acta de diputado: "No estoy acusado de nada"
# Author: marca.com
# Published At: 2024-02-27T13:58:19Z
# Source: Marca
# URL: https://www.marca.com/tiramillas/actualidad/2024/02/27/65ddc005268e3ef7618b4576.html
#
# Title: Wyoming ironiza sobre la negativa de Ábalos a dejar su acta de diputado: "Qué poco le gusta moverse"
# Author: marca.com
# Published At: 2024-02-27T09:05:18Z
# Source: Marca
# URL: https://www.marca.com/tiramillas/television/2024/02/27/65dda557e2704e34b68b45a4.html
#
# Title: Ábalos descarta dimitir pero admite que si el 'caso Koldo' hubiera estallado cuando era ministro sí lo habría hecho
# Author: Europa Press
# Published At: 2024-02-24T21:23:31Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/24/65da5dabe4d4d8bb3b8b459a.html
#
# Title: El PP apunta a Sánchez por el 'caso Koldo': "Le afecta directamente"
# Author: Juanma Lamet
# Published At: 2024-02-22T10:48:07Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d7232ce85ece84228b45c5.html
#
# Title: El alcalde de León (PSOE) revela cómo fue amenazado por Koldo García: "Me dijo que le quedaban tres años para joderme"
# Author: Marta Belver
# Published At: 2024-02-22T09:29:59Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d70b69fdddff1a7f8b45a5.html
#
# Title: La Audiencia Nacional intervino los teléfonos de la trama de Koldo tras 17 meses de investigación por Anticorrupción
# Author: Ángela Martialay, Gema Peñalosa
# Published At: 2024-02-22T01:39:46Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d6554ce4d4d8884d8b4583.html
#
# Title: Sánchez se desvincula de la trama de las mascarillas y niega que tuviera información cuando destituyó a Ábalos como ministro
# Author: Marta Belver
# Published At: 2024-02-21T17:35:28Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/21/65d5f0a2e4d4d8161b8b457c.html
#
# Title: La orden de detención de Koldo, el asesor de Ábalos: usó su "relación con autoridades" para cobrar comisiones "en efectivo"
# Author: Esteban Urreiztieta
# Published At: 2024-02-21T19:36:28Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/21/65d642e9e9cf4ae6208b45d2.html
#
# Title: El PP bautiza el caso como "la banda del Peugeot" y dice que Koldo, Ábalos, Cerdán y Sánchez "eran un clan"
# Author: Juanma Lamet
# Published At: 2024-02-27T12:50:41Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65ddd8dafc6c831d648b45bf.html
#
# Title: El PSOE insta a Ábalos a entregar su acta de diputado y le da 24 horas: "Aquí no caben los corruptos"
# Author: marca.com
# Published At: 2024-02-26T12:34:00Z
# Source: Marca
# URL: https://www.marca.com/tiramillas/actualidad/2024/02/26/65dc84ef46163fecbf8b458e.html
#
# Title: Un pinchazo apunta a la implicación de Ábalos: "Esto era un favor que le estaba pidiendo Koldo y su ex jefe"
# Author: Manuel Marraco
# Published At: 2024-02-23T11:52:27Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d882fbfdddff73148b4572.html
#
# Title: El PSOE exige a Ábalos que entregue el acta de diputado en un plazo de 24 horas: "Aquí no caben los corruptos"
# Author: Marta Belver
# Published At: 2024-02-26T10:22:16Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/26/65db187cfc6c83dc6c8b45b4.html
#
# Title: Koldo García usó la cuenta de su hija menor de edad para comprar un piso en Benidorm sin hipoteca
# Author: Gema Peñalosa, Noa de la Torre
# Published At: 2024-02-22T21:31:43Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d7b314e9cf4a90458b4571.html
#
# Title: El último intento de Ferraz para que Ábalos renuncie a su escaño en el Congreso: "Estamos seguros de que José Luis hará lo mejor para el PSOE"
# Author: Marta Belver
# Published At: 2024-02-26T19:37:45Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/26/65dcc163e85ecef9658b4582.html
#
# Title: Directo | El PP pide la dimisión de Ábalos: "No puede seguir ni un minuto más como diputado"
# Author: J. A.
# Published At: 2024-02-22T12:00:22Z
# Source: 20minutos.es
# URL: https://www.20minutos.es/noticia/5220988/0/directo-detencion-asesor-abalos-koldo-garcia-pp-pide-explicaciones-trama-mascarillas-comisiones-ilegales/
#
# Title: Detenido Koldo García Izaguirre, asesor del exministro José Luis Ábalos, por presunta corrupción en la compra de mascarillas
# Author: Europa Press, Gema Peñalosa
# Published At: 2024-02-21T11:26:14Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/21/65d5db96fdddffa91b8b45bb.html
#
# Title: El PSOE suspende a Ábalos de militancia para "salvaguardar la imagen del partido"
# Author: Marta Belver, Marisa Cruz, Vicente Coll
# Published At: 2024-02-27T14:38:33Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65ddf29821efa0e26b8b459a.html
#
# Title: La conexión Ábalos-Sánchez: "pata fuerte" desde el primer acto de la resurrección
# Author: Inma Lidón
# Published At: 2024-02-26T21:52:03Z
# Source: El Mundo
# URL: https://www.elmundo.es/comunidad-valenciana/2024/02/26/65dd049cfdddff769a8b458f.html
#
# Title: Detenido un asesor de Ábalos por cobrar comisiones en la compra de mascarillas
# Published At: 2024-02-23T21:37:55Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d8fb6ae9cf4a452e8b4584.html
#
# Title: El desafío de Ábalos pone a prueba la autoridad de Sánchez
# Author: Marisa Cruz
# Published At: 2024-02-27T19:30:25Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65de3239e4d4d8350c8b45ae.html
#
# Title: La expulsión de Ábalos conmociona al PSOE: "Es algo sin precedentes, hasta ayer era núcleo duro del sanchismo"
# Author: Marta Belver
# Published At: 2024-02-27T21:39:09Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65de47e221efa0d7418b45dd.html
#
# Title: El PP se personará en la causa judicial del 'caso Koldo': "Es indecente y sórdido"
# Author: Juanma Lamet
# Published At: 2024-02-23T07:37:39Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d84b3de9cf4a7f458b457d.html
#
# Title: El PSOE, a la espera de que Ábalos haga público un comunicado en el que dirá si renuncia o no al escaño
# Author: Marta Belver
# Published At: 2024-02-27T09:56:21Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65dd9302e4d4d82f0c8b45aa.html
#
# Title: Vox pide que Illa comparezca en el Parlament por el 'caso Koldo'
# Author: Víctor Mondelo, Vicente Coll
# Published At: 2024-02-26T11:57:10Z
# Source: El Mundo
# URL: https://www.elmundo.es/cataluna/2024/02/26/65dc7b41e85ece28558b4588.html
#
# Title: Sumar y PP tildan de "gravísimo" el 'caso Koldo' y reclaman al PSOE "todas las explicaciones"
# Author: Álvaro Carvajal, Marisa Cruz
# Published At: 2024-02-22T10:40:48Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d721cfe4d4d8884d8b45a1.html
#
# Title: La empresa zaragozana con la que el asesor de Ábalos contrató la compra de mascarillas mantenía una deuda con Hacienda de 269.989 euros
# Author: Javier Ortega
# Published At: 2024-02-22T10:22:15Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/22/65d71dcbe9cf4a662a8b45ce.html
#
# Title: José Luis Ábalos rechaza dimitir porque el escaño “quizá es propiedad de los españoles… pero también es un bien de mercado”
# Author: Kike García
# Published At: 2024-02-27T15:33:06Z
# Source: Elmundotoday.com
# URL: https://www.elmundotoday.com/2024/02/jose-luis-abalos-rechaza-dimitir-porque-el-escano-quiza-es-propiedad-de-los-espanoles-pero-tambien-es-un-bien-de-mercado/
#
# Title: El PP diseña un "calvario" parlamentario al PSOE sobre el 'caso Koldo'
# Author: Juanma Lamet
# Published At: 2024-02-26T00:51:25Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/26/65db6b6ae9cf4a4a2e8b458e.html
#
# Title: Ábalos, "muy decepcionado" y "estupefacto" por la detención de su asesor: "Sólo deseo que quede en nada"
# Author: Juanma Lamet
# Published At: 2024-02-21T13:18:35Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/21/65d5f7cbe85ecea8028b458a.html
#
# Title: Detenido un exasesor de Ábalos por cobrar comisiones en la compra de mascarillas
# Author: Expansión
# Published At: 2024-02-21T14:06:40Z
# Source: Expansion.com
# URL: https://www.expansion.com/economia/politica/2024/02/21/65d6036a468aeb34598b456d.html
#
# Title: Ábalos forzó a Puertos del Estado a comprar las mascarillas de la trama de Koldo: "Nos obligó"
# Author: Juanma Lamet
# Published At: 2024-02-23T13:31:16Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d8977de4d4d8be3b8b4572.html
#
# Title: El PSOE aísla a Cerdán y deja solo a Ábalos ante el escándalo del 'caso Koldo'
# Author: Marta Belver
# Published At: 2024-02-22T23:12:29Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d74723fc6c83bb2a8b4599.html
#
# Title: El canto del cisne
# Author: Santiago González
# Published At: 2024-02-23T23:08:56Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/24/65d8c944e4d4d8c03b8b457d.html
#
# Title: El Gobierno y Ábalos recurren a la vieja engañifa del Tribunal de Cuentas
# Author: Carlos Segovia
# Published At: 2024-02-27T21:38:46Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65de31b2e85ece3d598b45b9.html
#
# Title: ¿Quién va a pagar las facturas de Ábalos?
# Author: Iñaki Garay
# Published At: 2024-02-26T23:17:11Z
# Source: Expansion.com
# URL: https://www.expansion.com/economia/politica/2024/02/27/65dd02f9468aebdb768b45c7.html
#
# Title: Las frases lapidarias contra el PSOE y las alusiones a Sánchez del discurso de Ábalos: "Me enfrento a todo el poder político"
# Author: Vicente Coll
# Published At: 2024-02-27T14:48:41Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/27/65ddf30ffc6c83e6618b45c0.html
#
# Title: El PSOE empieza a presionar a Ábalos para que renuncie al escaño por su posible implicación en el 'caso Koldo': "Yo sé lo que haría"
# Author: Marta Belver
# Published At: 2024-02-23T12:17:30Z
# Source: El Mundo
# URL: https://www.elmundo.es/espana/2024/02/23/65d88498e9cf4a4f2e8b4571.html
#
# Title: El PP pedirá que Sánchez explique en el Senado la trama de las mascarillas: "Las responsabilidades no acaban en Ábalos"
# Author: Aitor Riveiro
# Published At: 2024-02-26T13:04:14Z
# Source: Eldiario.es
# URL: https://www.eldiario.es/politica/pp-pedira-sanchez-explique-senado-trama-mascarillas-responsabilidades-no-acaban-abalos_1_10958187.html
#
# Title: Carmen Fúnez (PP) exige a Pedro Sánchez que aclare las "amenazas" de Ábalos: "Es un presidente extorsionado"
# Author: Europa Press
# Published At: 2024-02-25T13:00:38Z
# Source: Eldiario.es
# URL: https://www.eldiario.es/castilla-la-mancha/politica/carmen-funez-pp-exige-pedro-sanchez-aclare-amenazas-abalos-presidente-extorsionado_1_10956225.html
#
# Title: Sumar apoyará la comisión de investigación del PSOE sobre el caso Koldo y "otras compras de material"
# Author: Daniel Ríos
# Published At: 2024-02-26T13:35:02Z
# Source: 20minutos.es
# URL: https://www.20minutos.es/noticia/5222097/0/sumar-apoyara-comision-investigacion-que-propondra-psoe-sobre-caso-koldo-otras-compras-material-pandemia/
# Title: El PSOE suspende cautelarmente a Ábalos por no entregar el acta y pasar al Grupo Mixto
# Author: Redacción HuffPost - Agencias
# Published At: 2024-02-27T15:07:50Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/el-psoe-suspende-cautelarmente-abalos-entregar-acta-pasar-grupo-mixto.html
#
# Title: Anticorrupción describe el poder del asesor de Ábalos: reuniones al máximo nivel y pliegos antes de ser publicados
# Author: Elena Herrera
# Published At: 2024-02-23T14:27:24Z
# Source: Eldiario.es
# URL: https://www.eldiario.es/politica/anticorrupcion-describe-asesor-abalos-reuniones-maximo-nivel-pliegos-publicados_1_10952468.html
#
# Title: Las 'sugerencias' de renuncia rodean a diputado español por un escándalo de corrupción
# Author: RT en Español
#  , RT en Español
# Published At: 2024-02-23T17:12:56Z
# Source: RT
# URL: https://actualidad.rt.com/actualidad/500120-psoe-puerta-salida-exministro-abalos-espana
#
# Title: Detenido un asesor del exministro Ábalos por presunta corrupción en la compra de mascarillas
# Author: Redacción HuffPost / EP
# Published At: 2024-02-21T11:13:32Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/sociedad/detenido-asesor-exministro-abalos-presunta-corrupcion-compra-mascarillas.html
#
# Title: El PSOE confirma que Ábalos anunciará su decisión esta mañana en un comunicado
# Author: Redacción HuffPost
# Published At: 2024-02-27T09:51:36Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/el-psoe-anuncia-abalos-anunciara-decision-mediante-comunicado.html
#
# Title: El PSOE expulsará a Ábalos al Grupo Mixto si no deja el escaño en las próximas horas
# Author: Redacción HuffPost / Agencias
# Published At: 2024-02-27T05:36:46Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/el-psoe-expulsara-abalos-grupo-mixto-deja-escano-proximas-horasbr.html
#
# Title: El Gobierno presiona a Ábalos para que dimita
# Author: Jose Manuel Sánchez
# Published At: 2024-02-23T11:38:12Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/el-gobierno-presiona-abalos-dimita.html
#
# Title: Ábalos mantiene su pulso al PSOE: no dimite
# Author: Redacción HuffPost
# Published At: 2024-02-27T10:18:48Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/abalos-mantiene-pulso-psoe-dimite.html
#
# Title: El PSOE pide a Ábalos que entregue el acta de diputado "en 24 horas"
# Author: Jose Manuel Sánchez
# Published At: 2024-02-26T10:24:14Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/el-psoe-pide-abalos-entregue-acta.html
#
# Title: Sánchez: "La lucha contra la corrupción ha de ser implacable, venga de donde venga y caiga quien caiga"
# Author: Europa Press
# Published At: 2024-02-24T10:10:32Z
# Source: Eldiario.es
# URL: https://www.eldiario.es/politica/sanchez-lucha-corrupcion-implacable-venga-venga-caiga-caiga_1_10954330.html
#
# Title: Koldo García y otros tres detenidos por el fraude de las mascarillas se niegan a declarar en la Audiencia Nacional
# Author: Pedro Águeda
# Published At: 2024-02-22T09:42:39Z
# Source: Eldiario.es
# Author: Eduardo Colom
# Published At: 2024-02-22T13:46:45Z
# Source: El Mundo
# URL: https://www.elmundo.es/baleares/2024/02/22/65d74893fdddffd49f8b459e.html
#
# Title: Abascal no se corta y se mofa de Ábalos al hablar así sobre su salida del PSOE: "Muy razonable"
# Author: Autor Redacción
# Published At: 2024-02-27T17:13:45Z
# Source: Mundodeportivo.com
# URL: https://www.mundodeportivo.com/actualidad/20240227/1002198753/abascal-corta-mofa-abalos-hablar-asi-sobre-salida-psoe-razonable-dct.html
#
# Title: Sánchez plantea una "salida personal" a Ábalos para zanjar el caso Koldo
# Author: Redacción HuffPost / Agencias
# Published At: 2024-02-26T05:37:03Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/sanchez-plantea-salida-personal-abalos-zanjar-caso-koldo.html
#
# Title: Ábalos renuncia a presidir la Comisión de Interior, pero de momento no dimite
# Author: Jose Manuel Sánchez
# Published At: 2024-02-26T14:21:18Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/abalos-renuncia-presidir-comision-interior-momento-dimite.html
#
# Title: Koldo García, el "último aizkolari socialista" que trabajó como asesor de Ábalos
# Author: J.E. / Redacción El HuffPost
# Published At: 2024-02-21T14:23:49Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/koldo-garcia-ultimo-aizkolari-socialista-trabajo-asesor-abalos.html
#
# Title: Alán Barroso te cuenta la corrupción del asesor de Ábalos y la hipocresía con el hermano de Ayuso
# Author: Alan Barroso
# Published At: 2024-02-22T15:00:14Z
# Source: Huffingtonpost.es
# URL: https://www.huffingtonpost.es/politica/la-corrupcion-asesor-abalos-hipocresia-hermano-ayuso.html

# %% [markdown]
# # Uso de Maisa con noticias en texto de la API

# %%
def convert_articles_to_dict(articles_list):
    # Crear un diccionario para almacenar las URLs categorizadas por fuente
    article_urls_dict = {}
    for article in articles_list:
        # Obtenemos el ID de la fuente
        source_id = article['source']['id']
        # Si la fuente aún no está en el diccionario, la añadimos
        if source_id not in article_urls_dict:
            article_urls_dict[source_id] = []
        # Añadimos la URL del artículo a la lista correspondiente a su fuente
        article_urls_dict[source_id].append(article['url'])
    return article_urls_dict

# %%
# Example usage:
from_date = "2024-02-26"
to_date = "2024-02-27"
query = "Ábalos&PSOE"
articles_response = search_articles(query, from_date, to_date, 'es', 3)

if articles_response:
    articles_data = process_article_urls(convert_articles_to_dict(articles_response['articles']))
    df = pd.DataFrame(articles_data)
else:
    print("Failed to retrieve articles")
# Out:
# https://newsapi.org/v2/everything?q=Ábalos&PSOE&from=2024-02-26&to=2024-02-27&language=es&apiKey=6ddc83d9e2974d0fabbac57924805fa3&pageSize=3

# %%
api_key = "sk_live_QgMwc89NHPxhEaD6CeYPMx_kLFsPqUz8ciTP3ErH5L24t" #Enter the API key
from maisa import Maisa
import requests

maisa = Maisa(
    # Jesus's Api
    api_key= api_key,
)

language = 'es' # Si no se especifica es inglés 
summary_length = 'medium' #(short, medium, long)

# %%
# Topic and Purpose
# Target Audience
# Quotes or Sources

def query_generator(df_texts,df_sources, language_query='en',purpose='breaking news',target='general public'):
    i=0
    query = f"You are tasked with crafting a comprehensive news article for a specific publication. This article will address a current issue or topic of interest, drawing upon {len(df_texts)+1} articles to provide a well-rounded perspective in the language {language_query}. "
    for i in range(0, len(df_texts)):
        summary = maisa.capabilities.summarize(
            text = df_texts[i], # (Required)
            lang = language,
            length = summary_length,
        )
        query += f"This is the article number {i+1} from the source "+ df_sources[i] +": "
        query += summary.summary+ " "
    query += "After providing the details of the source articles, you will be asked to integrate this information into a coherent and well-structured news article, adhering to a style for the "+ target +" and the style is of "+ purpose +"."
    return query

# %%
# Example
query_generator(df['text'],df['source'],'es')
# Out:
# 'You are tasked with crafting a comprehensive news article for a specific publication. This article will address a current issue or topic of interest, drawing upon 4 articles to provide a well-rounded perspective in the language es. This is the article number 1 from the source marca: El exministro José Luis Ábalos ha decidido mantener su escaño en el Congreso de los Diputados a pesar del ultimátum del PSOE para que dejara su acta de diputado. Ábalos anunció su dimisión como presidente de la Comisión de Interior, pero mantuvo su acta de diputado. En una comparecencia en la sala de prensa del Congreso, Ábalos afirmó que no está acusado de nada y que no tiene ningún enriquecimiento ilícito. Además, anunció que pasará al grupo mixto del Congreso. El PSOE ha suspendido de militancia a Ábalos tras esta decisión.\nThis is the article number 2 from the source marca: El panorama político está a la espera de la decisión de José Luis Ábalos sobre si dejará su acta de diputado con el PSOE. En el programa de televisión \'El Intermedio\', el presentador Wyoming hizo varios comentarios irónicos sobre la situación y analizó las decisiones del PSOE en relación a las transacciones de compra de material sanitario durante la pandemia. Ábalos se enfrenta a su propio partido y si no cumple con el plazo establecido, pasaría a formar parte del grupo mixto y perdería su aforamiento. Existen especulaciones sobre su posible implicación en el \'caso Koldo\'.\nThis is the article number 3 from the source el-mundo: El Partido Popular (PP) continúa presionando en el escándalo del \'caso Koldo\', acusando a una camarilla llamada "la banda del Peugeot" conformada por Koldo García Izaguirre, José Luis Ábalos, Santos Cerdán y Pedro Sánchez. El PP argumenta que es imposible que el presidente del Gobierno no tenga responsabilidad política en el caso. Además, el PP solicitará información sobre las contrataciones realizadas durante la pandemia entre Adif, Puertos del Estado, Correos y Telégrafos, y la empresa Soluciones de Gestión y Apoyo a Empresas SL. El objetivo es esclarecer la trama de corrupción y que los españoles conozcan qué ha sucedido con su dinero.\nAfter providing the details of the source articles, you will be asked to integrate this information into a coherent and well-structured news article, adhering to a style for the general public and the style is of breaking news.'

# %%
url = "https://api.maisa.ai/v1/kpu/run?explain_steps=false&retries=1"

query = query_generator(df['text'],df['source'],'es')

payload = "-----011000010111000001101001\r\nContent-Disposition: form-data; name=\"query\"\r\n\r\n"+ query +"\r\n-----011000010111000001101001--\r\n\r\n"

headers = {
    "X-API-Key": api_key,
    "accept": "application/json",
    "content-type": "multipart/form-data; boundary=---011000010111000001101001"
}

response = requests.post(url, data=payload, headers=headers)

print(response.text)
# Out:
# <html>
# <head><title>504 Gateway Time-out</title></head>
# <body>
# <center><h1>504 Gateway Time-out</h1></center>
# </body>
# </html>
